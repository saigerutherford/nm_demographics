# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pt_df_w_hcp = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/lifespan_29K_82sites_train/blr_metrics_hcp_white.csv')
pt_df_b_hcp = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/lifespan_29K_82sites_train/blr_metrics_hcp_black.csv')
pt_df_a_hcp = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/lifespan_29K_82sites_train/blr_metrics_hcp_asian.csv')

# %%
r_df_w_hcp = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/hcp_race_modeled_whitetest/blr_metrics.csv')
r_df_b_hcp = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/hcp_race_modeled_blacktest/blr_metrics.csv')
r_df_a_hcp = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/hcp_race_modeled_asiantest/blr_metrics.csv')

# %%
rn_df_w_hcp = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/hcp_race_not_modeled_whitetest/blr_metrics.csv')
rn_df_b_hcp = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/hcp_race_not_modeled_blacktest/blr_metrics.csv')
rn_df_a_hcp = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/hcp_race_not_modeled_asiantest/blr_metrics.csv')

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(pt_df_a_hcp['EV'])
axs[0].set_title('Asian EV')
axs[1].hist(pt_df_b_hcp['EV'])
axs[1].set_title('Black EV')
axs[2].hist(pt_df_w_hcp['EV'])
axs[2].set_title('White EV');

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(r_df_a_hcp['EV'])
axs[0].set_title('Asian EV')
axs[1].hist(r_df_b_hcp['EV'])
axs[1].set_title('Black EV')
axs[2].hist(r_df_w_hcp['EV'])
axs[2].set_title('White EV');

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(rn_df_a_hcp['EV'])
axs[0].set_title('Asian EV')
axs[1].hist(rn_df_b_hcp['EV'])
axs[1].set_title('Black EV')
axs[2].hist(rn_df_w_hcp['EV'])
axs[2].set_title('White EV');

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(pt_df_a_hcp['Skew'])
axs[0].set_title('Asian Skew')
axs[1].hist(pt_df_b_hcp['Skew'])
axs[1].set_title('Black Skew')
axs[2].hist(pt_df_w_hcp['Skew'])
axs[2].set_title('White Skew');

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(r_df_a_hcp['Skew'])
axs[0].set_title('Asian Skew')
axs[1].hist(r_df_b_hcp['Skew'])
axs[1].set_title('Black Skew')
axs[2].hist(r_df_w_hcp['Skew'])
axs[2].set_title('White Skew');

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(rn_df_a_hcp['Skew'])
axs[0].set_title('Asian Skew')
axs[1].hist(rn_df_b_hcp['Skew'])
axs[1].set_title('Black Skew')
axs[2].hist(rn_df_w_hcp['Skew'])
axs[2].set_title('White Skew');

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(pt_df_a_hcp['Kurtosis'])
axs[0].set_title('Asian Kurtosis')
axs[1].hist(pt_df_b_hcp['Kurtosis'])
axs[1].set_title('Black Kurtosis')
axs[2].hist(pt_df_w_hcp['Kurtosis'])
axs[2].set_title('White Kurtosis');

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(r_df_a_hcp['Kurtosis'])
axs[0].set_title('Asian Kurtosis')
axs[1].hist(r_df_b_hcp['Kurtosis'])
axs[1].set_title('Black Kurtosis')
axs[2].hist(r_df_w_hcp['Kurtosis'])
axs[2].set_title('White Kurtosis');

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(rn_df_a_hcp['Kurtosis'])
axs[0].set_title('Asian Kurtosis')
axs[1].hist(rn_df_b_hcp['Kurtosis'])
axs[1].set_title('Black Kurtosis')
axs[2].hist(rn_df_w_hcp['Kurtosis'])
axs[2].set_title('White Kurtosis');

# %%
pt_df_w_ukb = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/lifespan_29K_82sites_train/blr_metrics_ukb_white.csv')
pt_df_b_ukb = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/lifespan_29K_82sites_train/blr_metrics_ukb_black.csv')
pt_df_a_ukb = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/lifespan_29K_82sites_train/blr_metrics_ukb_asian.csv')

# %%
r_df_w_ukb = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/ukb_race_modeled_whitetest/blr_metrics.csv')
r_df_b_ukb = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/ukb_race_modeled_blacktest/blr_metrics.csv')
r_df_a_ukb = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/ukb_race_modeled_asiantest/blr_metrics.csv')

# %%
rn_df_w_ukb = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/ukb_race_not_modeled_whitetest/blr_metrics.csv')
rn_df_b_ukb = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/ukb_race_not_modeled_blacktest/blr_metrics.csv')
rn_df_a_ukb = pd.read_csv('/Users/saigerutherford/Documents/Work/drive-download-20220731T221458Z-001/braincharts/models/ukb_race_not_modeled_asiantest/blr_metrics.csv')

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(pt_df_a_ukb['EV']);
#axs[0].set_title('Asian EV')
axs[1].hist(pt_df_b_ukb['EV']);
#axs[1].set_title('Black EV')
axs[2].hist(pt_df_w_ukb['EV']);
#axs[2].set_title('White EV');

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(r_df_a_ukb['EV']);
#axs[0].set_title('Asian EV')
axs[1].hist(r_df_b_ukb['EV']);
#axs[1].set_title('Black EV')
axs[2].hist(r_df_w_ukb['EV']);
#axs[2].set_title('White EV');

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(rn_df_a_ukb['EV']);
#axs[0].set_title('Asian EV')
axs[1].hist(rn_df_b_ukb['EV']);
#axs[1].set_title('Black EV')
axs[2].hist(rn_df_w_ukb['EV']);
#axs[2].set_title('White EV');

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(pt_df_a_ukb['Skew']);
#axs[0].set_title('Asian Skew')
axs[1].hist(pt_df_b_ukb['Skew']);
#axs[1].set_title('Black Skew')
axs[2].hist(pt_df_w_ukb['Skew']);
#axs[2].set_title('White Skew')

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(r_df_a_ukb['Skew']);
#axs[0].set_title('Asian Skew')
axs[1].hist(r_df_b_ukb['Skew']);
#axs[1].set_title('Black Skew')
axs[2].hist(r_df_w_ukb['Skew']);
#axs[2].set_title('White Skew');

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(rn_df_a_ukb['Skew']);
#axs[0].set_title('Asian Skew')
axs[1].hist(rn_df_b_ukb['Skew']);
#axs[1].set_title('Black Skew')
axs[2].hist(rn_df_w_ukb['Skew']);
#axs[2].set_title('White Skew');

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(pt_df_a_ukb['Kurtosis']);
#axs[0].set_title('Asian Kurtosis')
axs[1].hist(pt_df_b_ukb['Kurtosis']);
#axs[1].set_title('Black Kurtosis')
axs[2].hist(pt_df_w_ukb['Kurtosis']);
#axs[2].set_title('White Kurtosis')

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(r_df_a_ukb['Kurtosis']);
#axs[0].set_title('Asian Kurtosis')
axs[1].hist(r_df_b_ukb['Kurtosis']);
#axs[1].set_title('Black Kurtosis')
axs[2].hist(r_df_w_ukb['Kurtosis']);
#axs[2].set_title('White Kurtosis')

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharex=True)
axs[0].hist(rn_df_a_ukb['Kurtosis']);
#axs[0].set_title('Asian Kurtosis')
axs[1].hist(rn_df_b_ukb['Kurtosis']);
#axs[1].set_title('Black Kurtosis')
axs[2].hist(rn_df_w_ukb['Kurtosis']);
#axs[2].set_title('White Kurtosis')
